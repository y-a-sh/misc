# %%
import random
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.linspace(-10,10,100)
y = 8*X*X-X*(np.random.random_sample(len(X)) + 0.5)*24.5 + 4
X = X.reshape(len(X), 1)
plt.scatter(X, y)

# %%
def compute_cost(X, y, theta):
    return 1./len(y) * np.linalg.norm(X @ theta - y) ** 2

# %%
def grad(X, y, theta):
    return X.T @ (X @ theta - y) - 4*theta

# %%
def grad_descent(X, y, learning_rate, S):
    X = np.hstack((np.ones((X.shape[0], 1)), X, X*X))
    params = np.zeros(X.shape[1])
    m = X.shape[0]
    for i in range(0, S):
        params -=  learning_rate * grad(X, y, params)
        print(params)
    return params
grad_descent(X, y, 0.001, 5000)
# Out:
# [  27.53046312  -78.55247328 1674.55173323]
# [-5.64218554e+03  1.09712150e+02 -3.45270101e+05]
# [ 1.16907784e+06 -3.41496665e+02  7.15368907e+07]
# [-2.42216727e+08  7.39903500e+02 -1.48214584e+10]
# [ 5.01839754e+10 -1.85185951e+03  3.07080238e+12]
# [-1.03974297e+13  4.35978855e+03 -6.36228028e+14]
# [ 2.15420445e+15 -1.05261483e+04  1.31817699e+17]
# [-4.46321541e+17  2.51120031e+04 -2.73108146e+19]
# [ 9.24716862e+19 -7.96451489e+04  5.65842526e+21]
# [-1.91588619e+22  1.57577282e+07 -1.17234791e+24]
# [ 3.96945273e+24 -4.24478680e+09  2.42894366e+26]
# [-8.22416024e+26  3.12397583e+11 -5.03243727e+28]
# [1.70393291e+29 3.69134689e+12 1.04265180e+31]
# [-3.53031470e+31 -2.84524264e+14 -2.16023117e+33]
# [7.31432662e+33 4.94344175e+18 4.47570193e+35]
# [-1.51542790e+36 -9.77289013e+20 -9.27303897e+37]
# [ 3.13975823e+38 -1.75066516e+23  1.92124617e+40]
# [-6.50514732e+40  3.88193445e+25 -3.98055787e+42]
# [ 1.34777707e+43 -2.81323923e+27  8.24716857e+44]
# ...
